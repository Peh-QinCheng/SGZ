# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Apr 11 01:08:27 2016

@author: pehqincheng
"""
## Need to label graph by subzone also
import networkx as nx
import matplotlib.pyplot as plt
import random 
import copy
import csv
import math

#Combines an array of subgraphs into a final graph
def combine_graph(graph_array):
    graphIndex = {}
    anchor_graph = graph_array.pop(0)
    for subgraph in graph_array:
        ## Create start end index for range
        start = len(anchor_graph)
        end = start + len(subgraph)
        mapping=dict(zip(subgraph.nodes(),range(start,end)))
        graphIndex[subgraph[0]['name']] = (start, end)
        ## make new graph that is relabelled
        rlb_graph = nx.relabel_nodes(subgraph,mapping)
        ## Add relabelled graph into anchor graph
        anchor_graph.add_nodes_from(rlb_graph.nodes(data=True))
        anchor_graph.add_edges_from(rlb_graph.edges(data=True))
    return anchor_graph, graphIndex

def createGraph(subZoneData):
    outputGraph = nx.erdos_renyi_graph(0,0)#init empty graph object
    lenCounter = 0 #save the length of current output
    for subzone in subZoneData:
        #Create subgraph from the data
        subgraph = nx.erdos_renyi_graph(subzone['pop'],subzone['prob']/10.0)
        nx.set_node_attributes(subgraph,'planningArea',subzone['planningArea'])
        nx.set_node_attributes(subgraph,'name',subzone['name'])
        nx.set_node_attributes(subgraph,'status','S') #Set node to S
        #Organise and join subgraph into final graph
        start = lenCounter
        end = lenCounter + len(subgraph)
        subzone['nodeIndex'] = (start, end) #Store the index of the nodes for future reference
        mapping=dict(zip(subgraph.nodes(),range(start,end)))
        rlb_graph = nx.relabel_nodes(subgraph,mapping)
        outputGraph.add_nodes_from(rlb_graph.nodes(data=True))
        outputGraph.add_edges_from(rlb_graph.edges(data=True))
        
        lenCounter += len(subgraph)
    return outputGraph

"""
Reads the CSV file and returns:
row_con: Array of dicts with each dict representing one subzone
loc_count: Array for number of people infected for each subzone. Zero initalised
loc_coord: Array of tuples representing the centroid coords for each subzone
pop: Array of population for each subzone
"""
#Reads CSV file and return data
def read_csv(csv_path):
    data = []
    with open(csv_path, 'rb') as f:
        reader = csv.reader(f)
        reader.next()
        for row in reader:
            name = row[1]
            coords = (float(row[11].replace(",","")), float(row[12].replace(",","")))
            con = {'name':name, 'planningArea':row[3], 'pop':int(row[9]), 'prob':float(row[10]), 'coords': coords, 'infected':0}           
            data.append(con)
    return data

#Coinflip to determine if infected
def flip(p):
    return 'I' if random.random() <= p else 'S'


#Variables init
perc = 5
#Infection probability
inf_prob = 0.4 

#Array to store each subgraph
subGraphArray = []

#Final graph
finalGraph = 0

#Total number of nodes
totalNodes = 0

"""
Construct the graph by:
reading csv into subZoneData
create subgraph into subGraphArray
create final graph into f_graph
"""
#Read data from CSV
subZoneData = read_csv('population2.csv')
"""
#Create subgraphs
for subzone in subZoneData:
    #Create an ErdosRenyiGraph for each subzone
    subgraph = nx.erdos_renyi_graph(subzone['nodes_num'],subzone['prob']/10.0)
    nx.set_node_attributes(subgraph,'planningArea',subzone['planningArea'])
    nx.set_node_attributes(subgraph,'name',subzone['name'])
    nx.set_node_attributes(subgraph,'status','S') #Set node to S
    subGraphArray.append(subgraph)

finalGraph = combine_graph(subGraphArray)
for i in finalGraph.nodes():
    finalGraph.node[i]['status'] = 'S'
"""
finalGraph = createGraph(subZoneData)

# %%
#DEBUG
print "Number of nodes: %d" %nx.number_of_nodes(finalGraph)
print "Number of edges: %d" %nx.number_of_edges(finalGraph)
for subzone in subZoneData:
    print subzone

# %%
#Gravity Model
"""
neighbors = {}
distances = []
for location,coord in loc_coord.iteritems():
    gravities = []
    #If current location has no population, skip
    if pop[location] == 0:
        continue
    for key,value in loc_coord.iteritems():
        dist = math.sqrt( (coord[0] - value[0])**2 + (coord[1] - value[1])**2 )
        #If same location or no population in target area, skip
        if dist == 0 or pop[key] == 0:
            continue
        #Gravity value
        G = float(pop[location]*pop[key])/dist**2
        gravities.append([G,key])
    #Sort gravities by descending order according to G
    gravities = sorted(gravities,key=lambda x: x[0],reverse=True)
    #Choose first 4 gravities (Largest 4)
    for i in gravities[:4]:
        distances.append(i[0])
    neighbors[location] = gravities[:4]
    
distances.sort()
print len(distances)
"""

def gravity(subZoneData):
    distances = []
    for subzoneA in subZoneData:
        location = subzoneA['name']
        if subzoneA['pop'] == 0:
            continue
        #init values
        gravities = []
        coordA = subzoneA['coords']
        for subzoneB in subZoneData:
            if subzoneA['name'] == subzoneB['name'] or subzoneB['pop'] == 0:
                continue
            coordB = subzoneB['coords']
            distSquared =  (coordA[0] - coordB[0])**2 + (coordA[1] - coordB[1])**2
            g = float(subzoneA['pop'] * subzoneB['pop'])/distSquared
            gravities.append((g, subzoneB['name']))
            #Sort gravities by descending order according to G
        gravities = sorted(gravities,key=lambda x: x[0],reverse=True)
        #Choose first 4 gravities (Largest 4)
        for i in gravities[:4]:
            distances.append(i[0])
        subzoneA['neighbours'] = gravities[:4]
    return distances

distances = gravity(subZoneData)
distances.sort()

for i in subZoneData:
    print i
# Out:
# {'nodeIndex': (0, 0), 'planningArea': 'Marina South', 'name': 'Marina South', 'pop': 0, 'coords': (31595.835746, 29220.187377), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Marina East', 'name': 'Marina East', 'pop': 0, 'coords': (32344.048918, 30103.249579), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Western Islands', 'name': 'Jurong Island And Bukom', 'pop': 0, 'coords': (13012.880555, 27225.867494), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Western Islands', 'name': 'Sudong', 'pop': 0, 'coords': (15931.75865, 19579.069042), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Western Islands', 'name': 'Semakau', 'pop': 0, 'coords': (21206.333887, 20465.807546), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Southern Islands', 'name': 'Southern Group', 'pop': 0, 'coords': (29815.090035, 23412.586672), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Straits View', 'name': 'Straits View', 'pop': 0, 'coords': (30832.901788, 28194.084367), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Downtown Core', 'name': 'Maxwell', 'pop': 0, 'coords': (29392.047827, 29096.753923), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Downtown Core', 'name': 'Philip', 'pop': 0, 'coords': (29706.724254, 29744.907932), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Downtown Core', 'name': 'Bayfront Subzone', 'pop': 0, 'coords': (30806.241886, 29530.167087), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Downtown Core', 'name': 'Clifford Pier', 'pop': 0, 'coords': (30379.504159, 29776.433459), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Marine Parade', 'name': 'Marina East (MP)', 'pop': 0, 'coords': (33715.697529, 30512.247665), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Marine Parade', 'name': 'East Coast', 'pop': 0, 'coords': (36386.526196, 31338.901602), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Tua', 'name': 'Tuas View Extension', 'pop': 0, 'coords': (5092.894974, 26137.873531), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Pioneer', 'name': 'Pioneer Sector', 'pop': 0, 'coords': (8872.750171, 31423.443487), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Pioneer', 'name': 'Benoi Sector', 'pop': 0, 'coords': (11668.244178, 33336.526735), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Boon Lay', 'name': 'Shipyard', 'pop': 0, 'coords': (11970.142817, 32202.385405), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Jurong West', 'name': 'Safti', 'pop': 0, 'coords': (11290.267413, 35199.670488), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Jurong West', 'name': 'Chin Bee', 'pop': 0, 'coords': (14631.805947, 35240.970393), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Paya Lebar', 'name': 'Airport Road', 'pop': 0, 'coords': (35133.315461, 37075.318444), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Bukit Batok', 'name': 'Brickworks', 'pop': 0, 'coords': (17861.63647, 37527.334404), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Tua', 'name': 'Tengeh', 'pop': 0, 'coords': (7798.167716, 35535.612756), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Hougang', 'name': 'Lorong Halus', 'pop': 0, 'coords': (35870.256814, 39071.43841), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Paya Lebar', 'name': 'Paya Lebar West', 'pop': 0, 'coords': (36649.310669, 39403.487372), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Changi Bay', 'name': 'Changi Bay', 'pop': 0, 'coords': (49502.486696, 34316.544261), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Tampines', 'name': 'Tampines North', 'pop': 0, 'coords': (39763.942304, 38698.169237), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Paya Lebar', 'name': 'Paya Lebar', 'pop': 0, 'coords': (36691.911385, 37730.723289), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Changi', 'name': 'Changi Airport', 'pop': 0, 'coords': (46661.849042, 36599.815818), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Ang Mo Kio', 'name': 'Yio Chu Kang North', 'pop': 0, 'coords': (29505.987773, 41733.440102), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Sengkang', 'name': 'Lorong Halus North', 'pop': 0, 'coords': (36619.215368, 40404.615733), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Seletar', 'name': 'Pulau Punggol Timor', 'pop': 0, 'coords': (34428.849172, 44535.897703), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Seletar', 'name': 'Pulau Punggol Barat', 'pop': 0, 'coords': (33050.097612, 45213.534713), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Woodlands', 'name': 'Woodlands Regional Centre', 'pop': 0, 'coords': (22571.209473, 46698.873522), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Simpang', 'name': 'Pulau Seletar', 'pop': 0, 'coords': (31511.014001, 47245.332956), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Simpang', 'name': 'Simpang North', 'pop': 0, 'coords': (29388.713987, 47645.276812), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Simpang', 'name': 'Tanjong Irau', 'pop': 0, 'coords': (29959.631236, 48428.17347), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Mandai', 'name': 'Mandai East', 'pop': 0, 'coords': (25739.27365, 45391.764856), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Simpang', 'name': 'Simpang South', 'pop': 0, 'coords': (30567.899832, 46241.496991), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Punggol', 'name': 'Punggol Canal', 'pop': 0, 'coords': (37408.842264, 43168.570259), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Mandai', 'name': 'Mandai West', 'pop': 0, 'coords': (22549.073671, 44455.847482), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Punggol', 'name': 'Coney Island', 'pop': 0, 'coords': (37928.497671, 43351.374303), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Sembawang', 'name': 'The Wharves', 'pop': 0, 'coords': (26945.06808, 49552.790419), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 0), 'planningArea': 'Central Water Catchment', 'name': 'Central Water Catchment', 'pop': 0, 'coords': (24424.418302, 39849.045629), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (0, 1), 'planningArea': 'North-Eastern Islands', 'name': 'North-Eastern Islands', 'pop': 1, 'neighbours': [(1.2172049213231563e-05, 'Tampines East'), (7.119828213756665e-06, 'Pasir Ris Drive'), (5.02028032887098e-06, 'Tampines West'), (4.695977162532835e-06, 'Bedok North')], 'coords': (50424.792351, 42612.878465), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 1), 'planningArea': 'Tengah', 'name': 'Tengah', 'pop': 0, 'coords': (16363.189322, 38432.547431), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 1), 'planningArea': 'Tua', 'name': 'Tuas View', 'pop': 0, 'coords': (5753.633739, 31501.454943), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 1), 'planningArea': 'Tua', 'name': 'Tuas Promenade', 'pop': 0, 'coords': (5918.995687, 34910.582131), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 1), 'planningArea': 'Jurong East', 'name': 'Penjuru Crescent', 'pop': 0, 'coords': (17651.309092, 31799.610294), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 1), 'planningArea': 'Pasir Ris', 'name': 'Pasir Ris Wafer Fab Park', 'pop': 0, 'coords': (38612.49655, 41196.681926), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 1), 'planningArea': 'Jurong East', 'name': 'Jurong River', 'pop': 0, 'coords': (16367.556025, 33519.992655), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 1), 'planningArea': 'Jurong East', 'name': 'Jurong Port', 'pop': 0, 'coords': (15250.743385, 32183.916018), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 1), 'planningArea': 'Boon Lay', 'name': 'Liu Fang', 'pop': 0, 'coords': (14079.10043, 33391.562358), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 1), 'planningArea': 'Paya Lebar', 'name': 'Paya Lebar East', 'pop': 0, 'coords': (38065.448389, 37522.396098), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (1, 2), 'planningArea': 'Lim Chu Kang', 'name': 'Lim Chu Kang', 'pop': 1, 'neighbours': [(2.0670745577826427e-05, 'Yew Tee'), (1.2702681977994772e-05, 'Choa Chu Kang North'), (1.1110274180770485e-05, 'Woodlands East'), (8.720010603275691e-06, 'Peng Siang')], 'coords': (15309.816883, 45819.041423), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (2, 2), 'planningArea': 'Boon Lay', 'name': 'Samulun', 'pop': 0, 'coords': (13418.49221, 32264.593334), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (2, 2), 'planningArea': 'Boon Lay', 'name': 'Tukang', 'pop': 0, 'coords': (14192.465474, 34209.550685), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (2, 2), 'planningArea': 'Sungei Kadut', 'name': 'Kranji', 'pop': 0, 'coords': (19766.843293, 46226.354531), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (2, 2), 'planningArea': 'Seletar', 'name': 'Seletar Aerospace Park', 'pop': 0, 'coords': (31690.730085, 43796.911754), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (2, 2), 'planningArea': 'Sengkang', 'name': 'Sengkang West', 'pop': 0, 'coords': (31319.94318, 41936.67866), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (2, 2), 'planningArea': 'Sungei Kadut', 'name': 'Reservoir View', 'pop': 0, 'coords': (18367.171084, 45940.48681), 'infected': 0, 'prob': 0.0}
# {'nodeIndex': (2, 2), 'planningArea': 'Tua', 'name': 'Tuas North', 'pop': 0, 'coords': (7737.032919, 34331.0852), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 2), 'planningArea': 'Tua', 'name': 'Tuas Bay', 'pop': 0, 'coords': (6921.158828, 33401.418917), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 2), 'planningArea': 'Clementi', 'name': 'Pandan', 'pop': 0, 'coords': (19228.603304, 32265.401001), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 2), 'planningArea': 'Sembawang', 'name': 'Senoko North', 'pop': 0, 'coords': (24665.787871, 49482.595336), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 2), 'planningArea': 'Sungei Kadut', 'name': 'Pang Sua', 'pop': 0, 'coords': (18535.567789, 43826.083647), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 2), 'planningArea': 'Pioneer', 'name': 'Gul Circle', 'pop': 0, 'coords': (9693.971254, 33074.429057), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 2), 'planningArea': 'Hougang', 'name': 'Defu Industrial Park', 'pop': 0, 'coords': (34951.396139, 37089.433099), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 2), 'planningArea': 'Pioneer', 'name': 'Gul Basin', 'pop': 0, 'coords': (10327.423367, 31746.761667), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 2), 'planningArea': 'Sembawang', 'name': 'Senoko South', 'pop': 0, 'coords': (25130.655028, 48346.032612), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 2), 'planningArea': 'Bukit Merah', 'name': 'City Terminals', 'pop': 0, 'coords': (28387.338879, 27536.567178), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (2, 11), 'planningArea': 'Western Water Catchment', 'name': 'Western Water Catchment', 'pop': 9, 'neighbours': [(0.0003627298311579184, 'Yunnan'), (0.0002617154443146931, 'Jurong West Central'), (0.00020591401135275768, 'Hong Kah'), (0.00012861381698445627, 'Boon Lay Place')], 'coords': (12020.342018, 40454.871099), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (11, 11), 'planningArea': 'Paya Lebar', 'name': 'Paya Lebar North', 'pop': 0, 'coords': (38291.978849, 39463.331911), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (11, 11), 'planningArea': 'Pioneer', 'name': 'Joo Koon', 'pop': 0, 'coords': (10883.946697, 34203.695968), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (11, 11), 'planningArea': 'Toa Payoh', 'name': 'Bidadari', 'pop': 0, 'coords': (32632.539491, 35918.015084), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (11, 12), 'planningArea': 'Queenstown', 'name': 'Port', 'pop': 1, 'neighbours': [(2.7145603525569508e-05, 'Pasir Panjang 1'), (1.659981189640127e-05, 'Clementi Woods'), (1.6276227250170065e-05, 'Clementi West'), (1.4243911074525978e-05, 'Dover')], 'coords': (21576.076592, 28788.217286), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (12, 12), 'planningArea': 'Bukit Merah', 'name': 'Singapore General Hospital', 'pop': 0, 'coords': (28147.221049, 29131.036839), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (12, 12), 'planningArea': 'Clementi', 'name': 'Toh Tuck', 'pop': 0, 'coords': (19433.120409, 34884.248145), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (12, 12), 'planningArea': 'Jurong East', 'name': 'International Business Park', 'pop': 0, 'coords': (18514.599516, 34285.797245), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (12, 12), 'planningArea': 'Serangoon', 'name': 'Serangoon North Ind Estate', 'pop': 0, 'coords': (31498.878438, 39642.222363), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (12, 12), 'planningArea': 'Woodlands', 'name': 'Senoko West', 'pop': 0, 'coords': (23921.551223, 48088.741009), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (12, 12), 'planningArea': 'Downtown Core', 'name': 'Marina Centre', 'pop': 0, 'coords': (30938.098572, 30471.826782), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (12, 12), 'planningArea': 'Jurong West', 'name': 'Kian Teck', 'pop': 0, 'coords': (12929.745193, 34857.753248), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (12, 13), 'planningArea': 'Sungei Kadut', 'name': 'Gali Batu', 'pop': 1, 'neighbours': [(0.0001569322056655147, 'Yew Tee'), (0.00010381071393414001, 'Saujana'), (8.597145351269961e-05, 'Choa Chu Kang North'), (8.332875683578168e-05, 'Senja')], 'coords': (20165.068789, 42429.240851), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (13, 13), 'planningArea': 'Ang Mo Kio', 'name': 'Yio Chu Kang', 'pop': 0, 'coords': (29443.74472, 40836.020709), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (13, 13), 'planningArea': 'Kallang', 'name': 'Kallang Bahru', 'pop': 0, 'coords': (31579.288968, 32929.527662), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (13, 13), 'planningArea': 'Jurong East', 'name': 'Jurong Gateway', 'pop': 0, 'coords': (17912.977827, 35033.906149), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (13, 13), 'planningArea': 'Geylang', 'name': 'Kallang Way', 'pop': 0, 'coords': (32761.492345, 34229.719203), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (13, 13), 'planningArea': 'Museum', 'name': 'Bras Basah', 'pop': 0, 'coords': (29793.093173, 30958.095292), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (13, 14), 'planningArea': 'Woodlands', 'name': 'Greenwood Park', 'pop': 1, 'neighbours': [(0.0004161321146413011, 'North Coast'), (0.0002909097560434805, 'Midview'), (0.0002357937130361126, 'Woodlands East'), (0.0001472748174029627, 'Woodlands West')], 'coords': (22608.389496, 47660.064534), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (14, 17), 'planningArea': 'Seletar', 'name': 'Seletar', 'pop': 3, 'neighbours': [(0.00040203198250822616, 'Fernvale'), (0.0003445404218539133, 'Anchorvale'), (0.00026522643584977654, 'Matilda'), (0.00023735212720911602, 'Sengkang Town Centre')], 'coords': (33371.549967, 43425.089587), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (17, 17), 'planningArea': 'Newton', 'name': 'Istana Negara', 'pop': 0, 'coords': (29226.828402, 31963.289418), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (17, 17), 'planningArea': 'Rochor', 'name': 'Rochor Canal', 'pop': 0, 'coords': (30693.783091, 31819.131669), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (17, 18), 'planningArea': 'Downtown Core', 'name': 'City Hall', 'pop': 1, 'neighbours': [(4.2944230988696345e-05, 'Crawford'), (3.949014123125457e-05, 'Chinatown'), (3.5252977099364994e-05, 'Bugis'), (3.28564987068284e-05, 'Victoria')], 'coords': (30209.073656, 30536.507919), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (18, 20), 'planningArea': 'Pasir Ris', 'name': 'Loyang West', 'pop': 2, 'neighbours': [(0.0004948873182869964, 'Pasir Ris Drive'), (0.00025295057910105844, 'Tampines East'), (7.619995519154203e-05, 'Pasir Ris Central'), (6.376014259113421e-05, 'Flora Drive')], 'coords': (43294.833739, 39888.771685), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (20, 21), 'planningArea': 'Sembawang', 'name': 'Sembawang East', 'pop': 1, 'neighbours': [(0.00019046171719673213, 'Northland'), (0.0001767720787024325, 'Yishun West'), (0.00015815551785067238, 'Admiralty'), (0.0001250755186182864, 'Sembawang Central')], 'coords': (27788.940315, 47682.832033), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (21, 23), 'planningArea': 'Queenstown', 'name': 'Singapore Polytechnic', 'pop': 2, 'neighbours': [(0.00041779062790780536, 'Ulu Pandan'), (0.0003500760519422569, 'Dover'), (0.000311082488091059, 'Clementi North'), (0.00020242978103240914, 'Clementi Woods')], 'coords': (21751.751031, 32627.894797), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (23, 30), 'planningArea': 'Sungei Kadut', 'name': 'Turf Club', 'pop': 7, 'neighbours': [(0.0006054952105330608, 'Woodgrove'), (0.00043576426068714147, 'Yew Tee'), (0.0003784872170351892, 'Woodlands West'), (0.00027372030295429964, 'Woodlands East')], 'coords': (20234.600671, 44507.190131), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (30, 34), 'planningArea': 'Queenstown', 'name': "National University of S'pore", 'pop': 4, 'neighbours': [(0.0006109167433131519, 'Dover'), (0.0003962632796754775, 'Clementi Woods'), (0.0002370109070561457, 'Clementi West'), (0.0001615911509802504, 'Clementi North')], 'coords': (21688.924357, 30930.121367), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (34, 37), 'planningArea': 'Punggol', 'name': 'Northshore', 'pop': 3, 'neighbours': [(0.00026831582845363006, 'Matilda'), (0.00024009175694870053, 'Waterway East'), (0.0002326744938656983, 'Punggol Town Centre'), (0.00022023691292362297, 'Punggol Field')], 'coords': (36169.55749, 44222.765568), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (37, 43), 'planningArea': 'Novena', 'name': 'Mount Pleasant', 'pop': 6, 'neighbours': [(0.0005108323032323665, 'Toa Payoh Central'), (0.000322360697231336, 'Toa Payoh West'), (0.0002810693234278713, 'Balestier'), (0.00025645286626805924, 'Upper Thomson')], 'coords': (27515.312527, 35112.618357), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (43, 62), 'planningArea': 'Tampines', 'name': 'Xilin', 'pop': 19, 'neighbours': [(0.002247405366560042, 'Tampines East'), (0.0018366619014149779, 'Simei'), (0.0012027521000030812, 'Bedok North'), (0.00118571388879901, 'Bedok South')], 'coords': (43110.614114, 34607.313266), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (62, 77), 'planningArea': 'Southern Islands', 'name': 'Sentosa', 'pop': 15, 'neighbours': [(0.00027435094879611684, 'Telok Blangah Rise'), (0.0001728530624361097, 'Tiong Bahru Station'), (0.00016875000766371822, 'Telok Blangah Drive'), (0.00016208148011397387, 'Everton Park')], 'coords': (27593.939399, 25813.354692), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (77, 83), 'planningArea': 'Queenstown', 'name': 'One North', 'pop': 6, 'neighbours': [(0.0015669539132279497, 'Tanglin Halt'), (0.0005994953837209696, 'Holland Drive'), (0.00047929582163065595, 'Mei Chin'), (0.0003886648509906526, 'Dover')], 'coords': (23299.243778, 31176.160569), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (83, 84), 'planningArea': 'Downtown Core', 'name': 'Raffles Place', 'pop': 1, 'neighbours': [(0.00014240495057386666, 'Chinatown'), (7.40442927819455e-05, 'China Square'), (4.804446921432651e-05, "Pearl's Hill"), (2.874486778563719e-05, 'Bukit Ho Swee')], 'coords': (29968.617588, 29572.761894), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (84, 94), 'planningArea': 'Jurong East', 'name': 'Lakeside', 'pop': 10, 'neighbours': [(0.0026621874944851636, 'Taman Jurong'), (0.002392245930721873, 'Yuhua East'), (0.0012462054359642337, 'Hong Kah'), (0.0009851207734279924, 'Yuhua West')], 'coords': (16697.011877, 35114.906266), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (94, 123), 'planningArea': 'Yishun', 'name': 'Lower Seletar', 'pop': 29, 'neighbours': [(0.005743946639725469, 'Yishun South'), (0.003665715543831745, 'Yishun East'), (0.0019011499553707055, 'Yishun West'), (0.0008011180923264063, 'Northland')], 'coords': (29437.619517, 43432.045462), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (123, 140), 'planningArea': 'Changi', 'name': 'Changi West', 'pop': 17, 'neighbours': [(0.002381875975605324, 'Pasir Ris Drive'), (0.0021060338067133344, 'Tampines East'), (0.0014871130044007874, 'Loyang East'), (0.0008302405872843646, 'Flora Drive')], 'coords': (44092.338009, 38928.658588), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (140, 141), 'planningArea': 'Orchard', 'name': 'Somerset', 'pop': 1, 'neighbours': [(8.315977207656e-05, 'Cairnhill'), (6.536561363107607e-05, 'Bukit Ho Swee'), (6.205940433017189e-05, 'Oxley'), (5.7432471109536874e-05, 'Leonie Hill')], 'coords': (28626.561107, 31494.904838), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (141, 150), 'planningArea': 'Yishun', 'name': 'Nee Soon', 'pop': 9, 'neighbours': [(0.0005400167550909226, 'Woodlands East'), (0.000513856252452594, 'Yishun West'), (0.00043032541063635723, 'Yishun South'), (0.0002862082643025838, 'Woodlands South')], 'coords': (25921.724542, 43261.522569), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (150, 152), 'planningArea': 'Museum', 'name': 'Fort Canning', 'pop': 2, 'neighbours': [(0.00011656923598059868, "Pearl's Hill"), (0.00010064933523594102, 'Bukit Ho Swee'), (9.574713321594079e-05, 'Chinatown'), (7.557302282924109e-05, 'Institution Hill')], 'coords': (29413.971802, 30713.072357), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (152, 155), 'planningArea': 'Queenstown', 'name': 'Queensway', 'pop': 3, 'neighbours': [(0.0009469800891881367, 'Mei Chin'), (0.0003272643221707266, 'Alexandra Hill'), (0.00019381697877367499, 'Tanglin Halt'), (0.00016218089620662204, 'Telok Blangah Drive')], 'coords': (24168.310667, 30104.176894), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (155, 156), 'planningArea': 'Singapore River', 'name': 'Clarke Quay', 'pop': 1, 'neighbours': [(0.00015650141683680997, "Pearl's Hill"), (0.00010404913728908453, 'Chinatown'), (6.586263530269707e-05, 'Bukit Ho Swee'), (4.7774241839250354e-05, 'Tiong Bahru')], 'coords': (29253.207379, 30222.864515), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (156, 161), 'planningArea': 'Downtown Core', 'name': 'Central Subzone', 'pop': 5, 'neighbours': [(0.0005084779995189633, 'Chinatown'), (0.0001398122524295101, 'Everton Park'), (0.00012420552551003523, "Pearl's Hill"), (9.728369188126664e-05, 'Bukit Ho Swee')], 'coords': (30125.836769, 28683.039949), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (161, 172), 'planningArea': 'Queenstown', 'name': 'Kent Ridge', 'pop': 11, 'neighbours': [(0.0008161910430750182, 'Mei Chin'), (0.0005185971850606253, 'Pasir Panjang 2'), (0.00046911866754310286, 'Alexandra Hill'), (0.000426180780339606, 'Tanglin Halt')], 'coords': (23464.840969, 29725.370665), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (172, 186), 'planningArea': 'Tanglin', 'name': 'Ridout', 'pop': 14, 'neighbours': [(0.0024290502309351424, 'Margaret Drive'), (0.0011446901101650844, 'Mei Chin'), (0.0006942132212357774, 'Alexandra Hill'), (0.0006706508083635966, 'Commonwealth')], 'coords': (25568.307761, 31752.668629), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (186, 187), 'planningArea': 'Downtown Core', 'name': 'Anson', 'pop': 1, 'neighbours': [(0.0002489940676074101, 'Chinatown'), (0.00013283553357115849, 'Everton Park'), (4.210811953927908e-05, "Pearl's Hill"), (4.1273887146696385e-05, 'Tanjong Pagar')], 'coords': (29145.350052, 28466.778334), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (187, 195), 'planningArea': 'Changi', 'name': 'Changi Point', 'pop': 8, 'neighbours': [(0.0003976568960642107, 'Tampines East'), (0.0003889438336047846, 'Pasir Ris Drive'), (0.0001296037858681066, 'Tampines West'), (0.00012063556287687765, 'Pasir Ris West')], 'coords': (44603.632679, 41360.418646), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (195, 197), 'planningArea': 'Downtown Core', 'name': 'Cecil', 'pop': 2, 'neighbours': [(0.0006731390330653354, 'Chinatown'), (9.653309510341179e-05, "Pearl's Hill"), (8.501438019743339e-05, 'Everton Park'), (7.079284576528942e-05, 'China Square')], 'coords': (29730.198354, 29011.328474), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (197, 199), 'planningArea': 'River Valley', 'name': 'Paterson', 'pop': 2, 'neighbours': [(0.00022964342683783512, 'Leonie Hill'), (0.00019681014785189336, 'Bukit Ho Swee'), (0.000146017949216709, 'One Tree Hill'), (0.00010847836185235112, 'Chatsworth')], 'coords': (27809.317106, 31511.373391), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (199, 203), 'planningArea': 'Orchard', 'name': 'Boulevard', 'pop': 4, 'neighbours': [(0.000388240801701957, 'Cairnhill'), (0.00021235669868528717, 'Bukit Ho Swee'), (0.00019339008853294838, 'Nassim'), (0.0001697247270959891, 'Orange Grove')], 'coords': (27916.927175, 31967.00646), 'infected': 0, 'prob': 0.06}
# {'nodeIndex': (203, 242), 'planningArea': 'Bukit Panjang', 'name': 'Nature Reserve', 'pop': 39, 'neighbours': [(0.002899257838912955, 'Hillview'), (0.0024843206001403315, 'Anak Bukit'), (0.0016689778761407332, 'Jelebu'), (0.0013283572134225562, 'Bangkit')], 'coords': (21822.627366, 37285.261554), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (242, 244), 'planningArea': 'Museum', 'name': 'Dhoby Ghaut', 'pop': 2, 'neighbours': [(9.808721462039802e-05, 'Mount Emily'), (9.182575161383701e-05, 'Oxley'), (8.764308721136628e-05, 'Bukit Ho Swee'), (7.470346802792975e-05, 'Kampong Java')], 'coords': (29320.073555, 31245.748357), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (244, 270), 'planningArea': 'Bukit Merah', 'name': 'Maritime Square', 'pop': 26, 'neighbours': [(0.003959454837825966, 'Telok Blangah Drive'), (0.0019426101267259745, 'Telok Blangah Rise'), (0.001845658591527229, 'Telok Blangah Way'), (0.0008961491449545542, 'Alexandra Hill')], 'coords': (25805.786756, 27911.419367), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (270, 272), 'planningArea': 'Rochor', 'name': 'Kampong Glam', 'pop': 2, 'neighbours': [(0.0008054368355928449, 'Crawford'), (0.00022906658096967793, 'Lavender'), (0.00018773163394606853, 'Sungei Road'), (0.00016187228276722337, 'Bugis')], 'coords': (30934.989044, 31623.148309), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (272, 274), 'planningArea': 'Newton', 'name': 'Newton Circus', 'pop': 2, 'neighbours': [(0.0002537182578616147, 'Moulmein'), (0.0002137559298422171, 'Cairnhill'), (0.0001502741612726396, 'Balestier'), (0.0001286716848615168, 'Kampong Java')], 'coords': (28587.162696, 32653.942841), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (274, 291), 'planningArea': 'Sembawang', 'name': 'Sembawang Straits', 'pop': 17, 'neighbours': [(0.0012669229250484688, 'Admiralty'), (0.001020933195464046, 'Yishun West'), (0.0010056872600502555, 'Northland'), (0.0008774515759519013, 'Woodlands East')], 'coords': (28352.477479, 48918.274998), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (291, 293), 'planningArea': 'Singapore River', 'name': 'Boat Quay', 'pop': 2, 'neighbours': [(0.0002593026941552197, 'Chinatown'), (0.0002483782868529421, 'China Square'), (0.000165745465112789, "Pearl's Hill"), (8.220162938673249e-05, 'Bukit Ho Swee')], 'coords': (29654.959448, 29974.655356), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (293, 302), 'planningArea': 'Kallang', 'name': 'Kampong Bugis', 'pop': 9, 'neighbours': [(0.0016717529147007866, 'Boon Keng'), (0.0014443697367106808, 'Aljunied'), (0.0009562838576586363, 'Tanjong Rhu'), (0.0009120222827785024, 'Bendemeer')], 'coords': (32138.221685, 32275.690787), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (302, 358), 'planningArea': 'Bukit Timah', 'name': 'Swiss Club', 'pop': 56, 'neighbours': [(0.0022711573707978024, 'Anak Bukit'), (0.0018246726601807875, 'Holland Road'), (0.0012892003695357706, 'Hillcrest'), (0.001131257675818642, 'Clementi North')], 'coords': (23436.268864, 35866.367975), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (358, 393), 'planningArea': 'Tanglin', 'name': 'Tyersall', 'pop': 35, 'neighbours': [(0.0020095740799599793, 'Farrer Court'), (0.0017938262057002957, 'Nassim'), (0.001089218604008344, 'Holland Drive'), (0.0009264603334156376, 'Margaret Drive')], 'coords': (25732.653606, 32985.849415), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (393, 423), 'planningArea': 'Pasir Ris', 'name': 'Pasir Ris Park', 'pop': 30, 'neighbours': [(0.010099860879678676, 'Pasir Ris Drive'), (0.0056343653936154516, 'Pasir Ris Central'), (0.0050948682715441776, 'Tampines East'), (0.0038573441668300606, 'Pasir Ris West')], 'coords': (41529.798067, 40218.94377), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (423, 462), 'planningArea': 'Yishun', 'name': 'Springleaf', 'pop': 39, 'neighbours': [(0.0025654543135386954, 'Yishun South'), (0.001979874640648468, 'Yishun West'), (0.0014620523759155983, 'Woodlands East'), (0.001440225663384071, 'Yishun East')], 'coords': (26969.723238, 42586.216027), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (462, 463), 'planningArea': 'Rochor', 'name': 'Mackenzie', 'pop': 1, 'neighbours': [(0.00015557050341614875, 'Kampong Java'), (0.00011255950244513497, 'Farrer Park'), (9.563260867138556e-05, 'Little India'), (6.977849199044109e-05, 'Balestier')], 'coords': (29680.018229, 32062.926337), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (463, 489), 'planningArea': 'Novena', 'name': 'Malcolm', 'pop': 26, 'neighbours': [(0.0027516569620736394, 'Toa Payoh Central'), (0.002270563199385299, 'Balestier'), (0.0016465845621203878, 'Moulmein'), (0.0009855379450978518, 'Nassim')], 'coords': (28070.258492, 33930.25682), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (489, 530), 'planningArea': 'Ang Mo Kio', 'name': 'Yio Chu Kang East', 'pop': 41, 'neighbours': [(0.008601206882853105, 'Cheng San'), (0.004824709282723255, 'Yio Chu Kang West'), (0.002739194925797359, 'Kebun Bahru'), (0.0026793792712932287, 'Seletar Hills')], 'coords': (30234.368248, 40602.650868), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (530, 552), 'planningArea': 'Pasir Ris', 'name': 'Loyang East', 'pop': 22, 'neighbours': [(0.005358534002433297, 'Pasir Ris Drive'), (0.0036521825787252282, 'Tampines East'), (0.0018502097539626705, 'Flora Drive'), (0.0014871130044007874, 'Changi West')], 'coords': (43592.331168, 38890.09487), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (552, 556), 'planningArea': 'Orchard', 'name': 'Tanglin', 'pop': 4, 'neighbours': [(0.0005134339244894172, 'One Tree Hill'), (0.0003237932073276222, 'Nassim'), (0.0002808447168142146, 'Chatsworth'), (0.0002121928249486854, 'Bukit Ho Swee')], 'coords': (27162.875763, 31905.732495), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (556, 640), 'planningArea': 'Ang Mo Kio', 'name': 'Tagore', 'pop': 84, 'neighbours': [(0.01076619029755436, 'Yio Chu Kang West'), (0.005355179688544382, 'Kebun Bahru'), (0.0031156737993392283, 'Sembawang Hills'), (0.0027805326188963114, 'Shangri-la')], 'coords': (27445.771303, 40971.424489), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (640, 649), 'planningArea': 'Newton', 'name': 'Goodwood Park', 'pop': 9, 'neighbours': [(0.0006947855332127039, 'Moulmein'), (0.0006100098786796541, 'Nassim'), (0.0005566170209804304, 'Balestier'), (0.00045063148925029853, 'Toa Payoh Central')], 'coords': (28108.880723, 32875.267006), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (649, 661), 'planningArea': 'Bukit Merah', 'name': 'Bukit Merah', 'pop': 12, 'neighbours': [(0.004190839126536725, 'Telok Blangah Way'), (0.0035571278921579983, 'Redhill'), (0.0032237144255861704, 'Henderson Hill'), (0.002251783851134087, 'Tiong Bahru Station')], 'coords': (26360.799077, 29384.142963), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (661, 736), 'planningArea': 'Bedok', 'name': 'Bayshore', 'pop': 75, 'neighbours': [(0.04198785212933542, 'Bedok South'), (0.012062473463613973, 'Bedok North'), (0.005134263222730052, 'Tampines East'), (0.0035052788333670964, 'Tampines West')], 'coords': (40835.377095, 32903.59658), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (736, 760), 'planningArea': 'Toa Payoh', 'name': 'Woodleigh', 'pop': 24, 'neighbours': [(0.005030774999179525, 'Potong Pasir'), (0.003286049047154845, 'Pei Chun'), (0.0030932751221141534, 'Serangoon Central'), (0.0020586603334554108, 'Bishan East')], 'coords': (31670.478565, 35799.90196), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (760, 863), 'planningArea': 'Bukit Timah', 'name': 'Holland Road', 'pop': 103, 'neighbours': [(0.007424107955828375, 'Ulu Pandan'), (0.006912903926311807, 'Anak Bukit'), (0.0065771591593466365, 'Clementi North'), (0.003652855223535425, 'Ghim Moh')], 'coords': (22485.01934, 34364.289655), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (863, 926), 'planningArea': 'Bukit Timah', 'name': 'Leedon Park', 'pop': 63, 'neighbours': [(0.009281181156690141, 'Holland Drive'), (0.004851194395450138, 'Ghim Moh'), (0.003535536555010718, 'Farrer Court'), (0.0033294433817851556, 'Coronation Road')], 'coords': (23947.764053, 33247.681154), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (926, 965), 'planningArea': 'Novena', 'name': 'Dunearn', 'pop': 39, 'neighbours': [(0.0015516136893676446, 'Nassim'), (0.001473042682670649, 'Hillcrest'), (0.001356320728776583, 'Toa Payoh Central'), (0.0010580137976910068, 'Balestier')], 'coords': (26525.527855, 34268.854767), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (965, 1053), 'planningArea': 'Bukit Timah', 'name': 'Hillcrest', 'pop': 88, 'neighbours': [(0.004335585632777556, 'Coronation Road'), (0.0018376119637211492, 'Upper Thomson'), (0.0015298511536924592, 'Toa Payoh Central'), (0.001473042682670649, 'Dunearn')], 'coords': (25207.842614, 35039.294248), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1053, 1063), 'planningArea': 'Bukit Merah', 'name': 'Alexandra North', 'pop': 10, 'neighbours': [(0.003241331316930409, 'Henderson Hill'), (0.0031787825251903034, 'Redhill'), (0.0014339894880082214, 'Chatsworth'), (0.001224181537961548, 'Tiong Bahru Station')], 'coords': (26548.250741, 30519.392217), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1063, 1078), 'planningArea': 'Yishun', 'name': 'Yishun Central', 'pop': 15, 'neighbours': [(0.011026183945903302, 'Yishun West'), (0.008197081898972901, 'Yishun East'), (0.006999979409969439, 'Yishun South'), (0.0029102912125699635, 'Northland')], 'coords': (28483.070511, 45383.334402), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1078, 1083), 'planningArea': 'Downtown Core', 'name': 'Tanjong Pagar', 'pop': 5, 'neighbours': [(0.0022581005487012367, 'Chinatown'), (0.0003935908136717835, 'Everton Park'), (0.00024495771918046276, "Pearl's Hill"), (0.00018044188836787182, 'Tiong Bahru')], 'coords': (29397.831047, 28706.351532), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1083, 1123), 'planningArea': 'Queenstown', 'name': 'Pasir Panjang 1', 'pop': 40, 'neighbours': [(0.0014507524809339555, 'Dover'), (0.0012030191497801514, 'Clementi Woods'), (0.000988864047046577, 'Clementi West'), (0.0009336348593613252, 'Mei Chin')], 'coords': (22077.338363, 29893.781283), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1123, 1166), 'planningArea': 'Sembawang', 'name': 'Sembawang Springs', 'pop': 43, 'neighbours': [(0.015345345691323892, 'Yishun West'), (0.012367272945550317, 'Sembawang Central'), (0.006215514084693198, 'Woodlands East'), (0.006062556179528895, 'Northland')], 'coords': (27076.811873, 46959.088654), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1166, 1249), 'planningArea': 'Tanglin', 'name': 'Nassim', 'pop': 83, 'neighbours': [(0.0025541163330117275, 'Balestier'), (0.0025213120483597263, 'Toa Payoh Central'), (0.0018743100006282799, 'Orange Grove'), (0.0017938262057002957, 'Tyersall')], 'coords': (27002.692813, 32905.576086), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1249, 1347), 'planningArea': 'Bukit Batok', 'name': 'Gombak', 'pop': 98, 'neighbours': [(0.02203216430531467, 'Jelebu'), (0.016888679265228062, 'Hong Kah North'), (0.01368914924528014, 'Teck Whye'), (0.007785256959460008, 'Keat Hong')], 'coords': (19560.702844, 39034.544), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1347, 1382), 'planningArea': 'Queenstown', 'name': 'Pasir Panjang 2', 'pop': 35, 'neighbours': [(0.0022124378214605027, 'Telok Blangah Drive'), (0.0014682860156993098, 'Mei Chin'), (0.0013720260865574677, 'Alexandra Hill'), (0.0006815942255859447, 'Depot Road')], 'coords': (23692.638502, 28894.409984), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1382, 1386), 'planningArea': 'Outram', 'name': "People's Park", 'pop': 4, 'neighbours': [(0.0027635907694140037, 'Chinatown'), (0.002120769768605733, "Pearl's Hill"), (0.0004343574148925449, 'Tiong Bahru'), (0.00039338714138148647, 'Everton Park')], 'coords': (28831.780735, 29419.645751), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1386, 1443), 'planningArea': 'Tanglin', 'name': 'Chatsworth', 'pop': 57, 'neighbours': [(0.007275776306850231, 'Bukit Ho Swee'), (0.00589284759306546, 'Henderson Hill'), (0.004450763910478113, 'Redhill'), (0.004301318483663797, 'Tiong Bahru Station')], 'coords': (26896.40192, 31045.01871), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1443, 1457), 'planningArea': 'Newton', 'name': 'Orange Grove', 'pop': 14, 'neighbours': [(0.0018743100006282799, 'Nassim'), (0.000573778108076592, 'Cairnhill'), (0.0005484977871999493, 'Balestier'), (0.00046363628047939494, 'Toa Payoh Central')], 'coords': (27668.184153, 32484.764067), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1457, 1519), 'planningArea': 'Bukit Timah', 'name': 'Coronation Road', 'pop': 62, 'neighbours': [(0.004335585632777556, 'Hillcrest'), (0.0033294433817851556, 'Leedon Park'), (0.0026684897088356105, 'Farrer Court'), (0.002098070464202476, 'Holland Drive')], 'coords': (24463.149083, 34200.333946), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1519, 1605), 'planningArea': 'Jurong West', 'name': 'Wenya', 'pop': 86, 'neighbours': [(0.019287879824215592, 'Boon Lay Place'), (0.01809095044467342, 'Yunnan'), (0.017925638596710397, 'Jurong West Central'), (0.01729781807519322, 'Hong Kah')], 'coords': (13953.527111, 37532.720904), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1605, 1659), 'planningArea': 'Bukit Panjang', 'name': 'Dairy Farm', 'pop': 54, 'neighbours': [(0.01636785868941511, 'Jelebu'), (0.013066835675532346, 'Bangkit'), (0.004412438435925331, 'Fajar'), (0.003490426440440201, 'Hillview')], 'coords': (21181.120069, 38939.837529), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1659, 1702), 'planningArea': 'Clementi', 'name': 'Faber', 'pop': 43, 'neighbours': [(0.008516236644800263, 'Clementi North'), (0.005858257496051656, 'West Coast'), (0.0034621305602110432, 'Clementi Central'), (0.002795577954091109, 'Teban Gardens')], 'coords': (19489.655948, 33800.866235), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1702, 1815), 'planningArea': 'Kallang', 'name': 'Tanjong Rhu', 'pop': 113, 'neighbours': [(0.015322394388601735, 'Aljunied'), (0.006073830027720483, 'Crawford'), (0.0046823766372501, 'Bendemeer'), (0.004674211144940059, 'Boon Keng')], 'coords': (32740.120813, 31438.308439), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1815, 1839), 'planningArea': 'Singapore River', 'name': 'Robertson Quay', 'pop': 24, 'neighbours': [(0.008729595870362433, 'Institution Hill'), (0.006806862136119463, 'Bukit Ho Swee'), (0.004257221187488584, "Pearl's Hill"), (0.0027387849268480455, 'Tiong Bahru')], 'coords': (28416.847706, 30409.36071), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1839, 1884), 'planningArea': 'Toa Payoh', 'name': 'Sennett', 'pop': 45, 'neighbours': [(0.0071748588899590415, 'Potong Pasir'), (0.006172653057571647, 'Macpherson'), (0.004740125222398227, 'Bendemeer'), (0.0033814440075919682, 'Aljunied')], 'coords': (32485.489891, 35050.196589), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1884, 1902), 'planningArea': 'River Valley', 'name': 'One Tree Hill', 'pop': 18, 'neighbours': [(0.0023065323654976274, 'Chatsworth'), (0.001536462954738466, 'Bukit Ho Swee'), (0.0007895790082615666, 'Henderson Hill'), (0.0007870377786705151, 'Nassim')], 'coords': (27315.559253, 31563.79681), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1902, 1905), 'planningArea': 'Rochor', 'name': 'Selegie', 'pop': 3, 'neighbours': [(0.001351517589150583, 'Bencoolen'), (0.0005935038340568314, 'Mount Emily'), (0.0002942922618941028, 'Victoria'), (0.00022690771354374534, 'Little India')], 'coords': (29817.330418, 31611.003951), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1905, 1915), 'planningArea': 'Newton', 'name': "Monk's Hill", 'pop': 10, 'neighbours': [(0.0015225776742413789, 'Cairnhill'), (0.0008472855675367588, 'Kampong Java'), (0.0007388075110488843, 'Moulmein'), (0.0006661124365191538, 'Balestier')], 'coords': (28922.845699, 32259.785627), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1915, 1926), 'planningArea': 'Rochor', 'name': 'Mount Emily', 'pop': 11, 'neighbours': [(0.0009433399162996855, 'Bencoolen'), (0.000750986346526869, 'Kampong Java'), (0.0005935038340568314, 'Selegie'), (0.0005512136338419781, 'Little India')], 'coords': (29583.255528, 31639.481057), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (1926, 2062), 'planningArea': 'Serangoon', 'name': 'Seletar Hills', 'pop': 136, 'neighbours': [(0.02119147699810156, 'Trafalgar'), (0.016425168683592624, 'Fernvale'), (0.014669418058968865, 'Serangoon North'), (0.012362340703285788, 'Cheng San')], 'coords': (31676.96269, 40603.198908), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2062, 2136), 'planningArea': 'Punggol', 'name': 'Punggol Town Centre', 'pop': 74, 'neighbours': [(0.029935686367771996, 'Matilda'), (0.010370364033070076, 'Sengkang Town Centre'), (0.008788529742634731, 'Punggol Field'), (0.00771946217295325, 'Rivervale')], 'coords': (35602.377726, 43427.511052), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2136, 2238), 'planningArea': 'Marine Parade', 'name': 'Mountbatten', 'pop': 102, 'neighbours': [(0.015571777488634983, 'Aljunied'), (0.009816442952188647, 'Geylang East'), (0.008912166896953542, 'Marine Parade'), (0.00515770835357583, 'Katong')], 'coords': (34449.704492, 31557.74461), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2238, 2384), 'planningArea': 'Woodlands', 'name': 'North Coast', 'pop': 146, 'neighbours': [(0.02096957406129656, 'Woodlands East'), (0.01963857291652366, 'Woodlands West'), (0.01809904251146777, 'Midview'), (0.009259777214446778, 'Woodgrove')], 'coords': (22147.036053, 48031.552239), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2384, 2575), 'planningArea': 'Jurong East', 'name': 'Teban Gardens', 'pop': 191, 'neighbours': [(0.0076843179645631355, 'Clementi North'), (0.006591344748993226, 'Taman Jurong'), (0.006394542728452646, 'Yuhua East'), (0.006302169175216876, 'West Coast')], 'coords': (17965.722517, 33016.3403), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2575, 2660), 'planningArea': 'Novena', 'name': 'Moulmein', 'pop': 85, 'neighbours': [(0.0171641914434817, 'Balestier'), (0.010849773029521262, 'Kampong Java'), (0.009079712144929652, 'Toa Payoh Central'), (0.006058437575739952, 'Bendemeer')], 'coords': (29057.441598, 33323.922176), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2660, 2729), 'planningArea': 'Bedok', 'name': 'Siglap', 'pop': 69, 'neighbours': [(0.016938928914085858, 'Frankel'), (0.007469904190315294, 'Bedok North'), (0.005455015518520973, 'Bedok South'), (0.004659309864134672, 'Kembangan')], 'coords': (38435.467925, 32101.88129), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2729, 2796), 'planningArea': 'Toa Payoh', 'name': 'Joo Seng', 'pop': 67, 'neighbours': [(0.01674803286797363, 'Macpherson'), (0.010089197408625065, 'Tai Seng'), (0.006655437562282302, 'Upper Paya Lebar'), (0.004643897041525999, 'Aljunied')], 'coords': (33454.06908, 35419.727691), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2796, 2859), 'planningArea': 'Clementi', 'name': 'Sunset Way', 'pop': 63, 'neighbours': [(0.02087546334660209, 'Clementi North'), (0.007927984990365608, 'Anak Bukit'), (0.0029762490122398847, 'Clementi Central'), (0.00229405928819984, 'Holland Road')], 'coords': (20805.313109, 34279.452195), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2859, 2883), 'planningArea': 'River Valley', 'name': 'Leonie Hill', 'pop': 24, 'neighbours': [(0.00391922189739957, 'Bukit Ho Swee'), (0.0024391966535157223, 'Institution Hill'), (0.0013295803865719165, 'Tiong Bahru Station'), (0.0011686290676953955, 'Tiong Bahru')], 'coords': (28082.939717, 31145.10796), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2883, 2897), 'planningArea': 'River Valley', 'name': 'Oxley', 'pop': 14, 'neighbours': [(0.0020622694433856744, 'Institution Hill'), (0.0011783790255509013, 'Bukit Ho Swee'), (0.0007033374851209976, "Pearl's Hill"), (0.0006388807929205657, 'Leonie Hill')], 'coords': (28802.355543, 31053.671768), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (2897, 3029), 'planningArea': 'Geylang', 'name': 'Kampong Ubi', 'pop': 132, 'neighbours': [(0.022710858489992266, 'Macpherson'), (0.022017276312859064, 'Geylang East'), (0.0213225564946103, 'Kaki Bukit'), (0.011223938895622924, 'Aljunied')], 'coords': (35039.549521, 34647.26336), 'infected': 0, 'prob': 0.09}
# {'nodeIndex': (3029, 3113), 'planningArea': 'Serangoon', 'name': 'Lorong Chuan', 'pop': 84, 'neighbours': [(0.02584491627674239, 'Serangoon Central'), (0.018431546530576496, 'Bishan East'), (0.012493864185579004, 'Serangoon Garden'), (0.006234360994579308, 'Chong Boon')], 'coords': (31327.762839, 36732.631681), 'infected': 0, 'prob': 0.12}
# {'nodeIndex': (3113, 3146), 'planningArea': 'Newton', 'name': 'Cairnhill', 'pop': 33, 'neighbours': [(0.001620223374102992, 'Balestier'), (0.0015511243998492094, 'Moulmein'), (0.0015225776742413789, "Monk's Hill"), (0.0014376453258765313, 'Kampong Java')], 'coords': (28482.667259, 32108.19192), 'infected': 0, 'prob': 0.12}
# {'nodeIndex': (3146, 3254), 'planningArea': 'Yishun', 'name': 'Khatib', 'pop': 108, 'neighbours': [(0.04018343219993893, 'Yishun South'), (0.0286853372754589, 'Yishun West'), (0.011439784650505314, 'Yishun East'), (0.006673824892738341, 'Woodlands East')], 'coords': (27480.635782, 44420.68844), 'infected': 0, 'prob': 0.12}
# {'nodeIndex': (3254, 3323), 'planningArea': 'Ang Mo Kio', 'name': 'Sembawang Hills', 'pop': 69, 'neighbours': [(0.01669490924892948, 'Kebun Bahru'), (0.011488761695828015, 'Yio Chu Kang West'), (0.010000945986317743, 'Shangri-la'), (0.005836331001759029, 'Upper Thomson')], 'coords': (27715.923623, 39634.529022), 'infected': 0, 'prob': 0.12}
# {'nodeIndex': (3323, 3462), 'planningArea': 'Bukit Batok', 'name': 'Bukit Batok South', 'pop': 139, 'neighbours': [(0.027314359103725726, 'Bukit Batok Central'), (0.02518109841816715, 'Bukit Batok East'), (0.012969525163991014, 'Anak Bukit'), (0.011799561731099065, 'Toh Guan')], 'coords': (19631.873014, 35910.96357), 'infected': 0, 'prob': 0.12}
# {'nodeIndex': (3462, 3798), 'planningArea': 'Bedok', 'name': 'Frankel', 'pop': 336, 'neighbours': [(0.08508841498457348, 'Kembangan'), (0.04807870649578586, 'Bedok North'), (0.025574793682910085, 'Marine Parade'), (0.02219302412532778, 'Bedok South')], 'coords': (37694.551929, 33007.267985), 'infected': 0, 'prob': 0.12}
# {'nodeIndex': (3798, 4101), 'planningArea': 'Bishan', 'name': 'Upper Thomson', 'pop': 303, 'neighbours': [(0.045410900195686506, 'Marymount'), (0.031832049591210006, 'Shangri-la'), (0.019480500598159752, 'Kebun Bahru'), (0.018168882427079418, 'Townsville')], 'coords': (27884.687241, 37749.393713), 'infected': 0, 'prob': 0.12}
# {'nodeIndex': (4101, 4321), 'planningArea': 'Bukit Timah', 'name': 'Anak Bukit', 'pop': 220, 'neighbours': [(0.012969525163991014, 'Bukit Batok South'), (0.012444665090968822, 'Clementi North'), (0.008736696086336397, 'Hillview'), (0.00845668658867505, 'Bukit Batok Central')], 'coords': (21127.191865, 35561.884058), 'infected': 0, 'prob': 0.12}
# {'nodeIndex': (4321, 4380), 'planningArea': 'Clementi', 'name': 'West Coast', 'pop': 59, 'neighbours': [(0.009515441694157866, 'Clementi North'), (0.007902994187870322, 'Clementi Central'), (0.006302169175216876, 'Teban Gardens'), (0.005858257496051656, 'Faber')], 'coords': (19293.762515, 33172.622898), 'infected': 0, 'prob': 0.12}
# ...
# {'nodeIndex': (21942, 22801), 'planningArea': 'Bedok', 'name': 'Bedok North', 'pop': 859, 'neighbours': [(0.23273532516354295, 'Bedok South'), (0.1674514302957142, 'Tampines West'), (0.11998912305315426, 'Tampines East'), (0.09518502942903467, 'Bedok Reservoir')], 'coords': (39429.210492, 34737.619447), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (22801, 23010), 'planningArea': 'Jurong East', 'name': 'Yuhua West', 'pop': 209, 'neighbours': [(0.07555759840902176, 'Hong Kah'), (0.051513546751235546, 'Yuhua East'), (0.024197194400060452, 'Bukit Batok West'), (0.023032266999352853, 'Taman Jurong')], 'coords': (16721.252554, 36571.264625), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (23010, 23195), 'planningArea': 'Ang Mo Kio', 'name': 'Shangri-la', 'pop': 185, 'neighbours': [(0.11410121013536369, 'Kebun Bahru'), (0.03280696298760327, 'Townsville'), (0.031832049591210006, 'Upper Thomson'), (0.022363794878857077, 'Yio Chu Kang West')], 'coords': (28564.715659, 38888.920991), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (23195, 23465), 'planningArea': 'Choa Chu Kang', 'name': 'Teck Whye', 'pop': 270, 'neighbours': [(0.08448156829515434, 'Senja'), (0.07309894063088315, 'Choa Chu Kang Central'), (0.04541967307938463, 'Jelebu'), (0.04055800760700068, 'Choa Chu Kang North')], 'coords': (19269.994202, 40394.105057), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (23465, 23587), 'planningArea': 'Bukit Merah', 'name': 'Tiong Bahru', 'pop': 122, 'neighbours': [(0.07880221716477884, 'Tiong Bahru Station'), (0.04719594147136463, 'Bukit Ho Swee'), (0.02226987010386348, 'Kampong Tiong Bahru'), (0.014006727041095233, 'Henderson Hill')], 'coords': (27785.672063, 29590.395179), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (23587, 23894), 'planningArea': 'Toa Payoh', 'name': 'Toa Payoh Central', 'pop': 307, 'neighbours': [(0.10538285309163314, 'Balestier'), (0.06640247796872313, 'Boon Teck'), (0.04750678243888015, 'Toa Payoh West'), (0.03587667904793995, 'Braddell')], 'coords': (29409.743867, 34982.196249), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (23894, 23999), 'planningArea': 'Bukit Merah', 'name': 'Kampong Tiong Bahru', 'pop': 105, 'neighbours': [(0.04498018498089887, 'Telok Blangah Rise'), (0.04418555038582969, 'Tiong Bahru Station'), (0.02226987010386348, 'Tiong Bahru'), (0.01880830443281789, 'Telok Blangah Way')], 'coords': (27335.830504, 28979.773186), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (23999, 24117), 'planningArea': 'Toa Payoh', 'name': 'Pei Chun', 'pop': 118, 'neighbours': [(0.04301993143570459, 'Boon Teck'), (0.04162007021653311, 'Lorong 8 Toa Payoh'), (0.03453409959995799, 'Kim Keat'), (0.018995324603137593, 'Potong Pasir')], 'coords': (30814.328258, 35440.970366), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (24117, 24269), 'planningArea': 'Bukit Batok', 'name': 'Bukit Batok West', 'pop': 152, 'neighbours': [(0.0553219634061113, 'Yuhua East'), (0.047965014679955904, 'Bukit Batok Central'), (0.024197194400060452, 'Yuhua West'), (0.017856173668408082, 'Toh Guan')], 'coords': (17865.88385, 36623.213409), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (24269, 24657), 'planningArea': 'Yishun', 'name': 'Yishun South', 'pop': 388, 'neighbours': [(0.10427904638624746, 'Yishun East'), (0.08848494096438753, 'Yishun West'), (0.04018343219993893, 'Khatib'), (0.025351606588599463, 'Northland')], 'coords': (28500.546741, 44471.673501), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (24657, 24944), 'planningArea': 'Clementi', 'name': 'Clementi North', 'pop': 287, 'neighbours': [(0.06228905108623489, 'Clementi Central'), (0.02087546334660209, 'Sunset Way'), (0.019554867262089673, 'Clementi Woods'), (0.015120551464922735, 'Clementi West')], 'coords': (20613.245075, 33368.822559), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (24944, 25107), 'planningArea': 'Bukit Merah', 'name': 'Bukit Ho Swee', 'pop': 163, 'neighbours': [(0.04938013475719582, 'Tiong Bahru Station'), (0.04719594147136463, 'Tiong Bahru'), (0.023538575995050586, 'Henderson Hill'), (0.011143608659007506, "Pearl's Hill")], 'coords': (27680.062794, 30230.861003), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (25107, 25382), 'planningArea': 'Jurong East', 'name': 'Yuhua East', 'pop': 275, 'neighbours': [(0.05976626037657516, 'Toh Guan'), (0.0553219634061113, 'Bukit Batok West'), (0.051513546751235546, 'Yuhua West'), (0.031239795340653877, 'Hong Kah')], 'coords': (17485.175464, 35841.780067), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (25382, 25673), 'planningArea': 'Sembawang', 'name': 'Sembawang Central', 'pop': 291, 'neighbours': [(0.08112012973177761, 'Woodlands East'), (0.05462292682267374, 'Sembawang North'), (0.033618974932764514, 'Yishun West'), (0.03278056145644143, 'Admiralty')], 'coords': (26268.732619, 47558.080474), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (25673, 25815), 'planningArea': 'Queenstown', 'name': 'Holland Drive', 'pop': 142, 'neighbours': [(0.028516640882122572, 'Tanglin Halt'), (0.02487755815463322, 'Commonwealth'), (0.02280235574304563, 'Ghim Moh'), (0.009281181156690141, 'Leedon Park')], 'coords': (23711.437056, 32294.772193), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (25815, 26364), 'planningArea': 'Yishun', 'name': 'Yishun East', 'pop': 549, 'neighbours': [(0.10427904638624746, 'Yishun South'), (0.10147449373438587, 'Yishun West'), (0.07741917516246395, 'Northland'), (0.019505868679207637, 'Woodlands East')], 'coords': (29476.599551, 45515.719641), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (26364, 26662), 'planningArea': 'Ang Mo Kio', 'name': 'Cheng San', 'pop': 298, 'neighbours': [(0.09206716389520359, 'Chong Boon'), (0.0672979821164682, 'Townsville'), (0.03681507277287811, 'Serangoon Garden'), (0.027334833951274434, 'Kebun Bahru')], 'coords': (30312.192396, 39413.347824), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (26662, 26900), 'planningArea': 'Bukit Panjang', 'name': 'Bangkit', 'pop': 238, 'neighbours': [(0.0972972032758665, 'Jelebu'), (0.07568527033810468, 'Fajar'), (0.03344800654339694, 'Saujana'), (0.014382627211531263, 'Senja')], 'coords': (21431.228619, 39899.527281), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (26900, 27166), 'planningArea': 'Ang Mo Kio', 'name': 'Yio Chu Kang West', 'pop': 266, 'neighbours': [(0.08485167052889181, 'Kebun Bahru'), (0.023759779958198845, 'Cheng San'), (0.022363794878857077, 'Shangri-la'), (0.01591610014494312, 'Townsville')], 'coords': (28750.497908, 40360.626299), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (27166, 27599), 'planningArea': 'Punggol', 'name': 'Punggol Field', 'pop': 433, 'neighbours': [(0.2351328903922378, 'Rivervale'), (0.18245639513329132, 'Waterway East'), (0.09868610239532008, 'Sengkang Town Centre'), (0.04006733559957677, 'Matilda')], 'coords': (36673.899432, 41847.090289), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (27599, 27721), 'planningArea': 'Bukit Merah', 'name': 'Redhill', 'pop': 122, 'neighbours': [(0.04593925015930465, 'Henderson Hill'), (0.026764721642274898, 'Alexandra Hill'), (0.015485631714995533, 'Tiong Bahru Station'), (0.009184135968793144, 'Telok Blangah Way')], 'coords': (26201.958019, 30005.703511), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (27721, 28065), 'planningArea': 'Choa Chu Kang', 'name': 'Choa Chu Kang North', 'pop': 344, 'neighbours': [(0.1758278690461748, 'Yew Tee'), (0.10704145426545861, 'Choa Chu Kang Central'), (0.04055800760700068, 'Teck Whye'), (0.038361029453521225, 'Peng Siang')], 'coords': (18347.568276, 41593.764897), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (28065, 28634), 'planningArea': 'Jurong West', 'name': 'Hong Kah', 'pop': 569, 'neighbours': [(0.12481529010144071, 'Boon Lay Place'), (0.07555759840902176, 'Yuhua West'), (0.07254840744520911, 'Taman Jurong'), (0.0690383600392235, 'Jurong West Central')], 'coords': (15507.934637, 36890.281065), 'infected': 0, 'prob': 0.15}
# {'nodeIndex': (28634, 30019), 'planningArea': 'Tampines', 'name': 'Tampines East', 'pop': 1385, 'neighbours': [(0.32584079839143476, 'Tampines West'), (0.24534525325075587, 'Simei'), (0.24419854302202446, 'Pasir Ris Drive'), (0.11998912305315426, 'Bedok North')], 'coords': (41122.547014, 37392.389082), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (30019, 30728), 'planningArea': 'Jurong West', 'name': 'Yunnan', 'pop': 709, 'neighbours': [(0.5470292588098363, 'Jurong West Central'), (0.06683114368235317, 'Boon Lay Place'), (0.045612482419903164, 'Hong Kah'), (0.02666258467366763, 'Taman Jurong')], 'coords': (12593.141256, 36299.933521), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (30728, 30930), 'planningArea': 'Bukit Panjang', 'name': 'Senja', 'pop': 202, 'neighbours': [(0.12620301816031967, 'Saujana'), (0.08448156829515434, 'Teck Whye'), (0.04042344787199431, 'Jelebu'), (0.03809167338869291, 'Fajar')], 'coords': (19897.946677, 40895.363768), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (30930, 31191), 'planningArea': 'Bukit Batok', 'name': 'Bukit Batok Central', 'pop': 261, 'neighbours': [(0.059127087488538246, 'Bukit Batok East'), (0.047965014679955904, 'Bukit Batok West'), (0.041431419707353326, 'Guilin'), (0.030379283069493154, 'Yuhua East')], 'coords': (18773.557894, 36680.052416), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (31191, 31474), 'planningArea': 'Bukit Batok', 'name': 'Hong Kah North', 'pop': 283, 'neighbours': [(0.03496895209024911, 'Guilin'), (0.027151956900409665, 'Bukit Batok Central'), (0.021924895583049688, 'Keat Hong'), (0.02032317584159323, 'Peng Siang')], 'coords': (18505.465338, 38307.468402), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (31474, 31785), 'planningArea': 'Jurong West', 'name': 'Boon Lay Place', 'pop': 311, 'neighbours': [(0.14990380789276334, 'Jurong West Central'), (0.12481529010144071, 'Hong Kah'), (0.06683114368235317, 'Yunnan'), (0.04059751000389563, 'Taman Jurong')], 'coords': (14403.778894, 36444.6275), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (31785, 31936), 'planningArea': 'Toa Payoh', 'name': 'Boon Teck', 'pop': 151, 'neighbours': [(0.06640247796872313, 'Toa Payoh Central'), (0.04301993143570459, 'Pei Chun'), (0.040274390651862495, 'Balestier'), (0.03361221780034841, 'Braddell')], 'coords': (30193.134932, 35272.747409), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (31936, 32531), 'planningArea': 'Pasir Ris', 'name': 'Pasir Ris Drive', 'pop': 595, 'neighbours': [(0.24419854302202446, 'Tampines East'), (0.08715197044871134, 'Pasir Ris Central'), (0.045221955225664724, 'Flora Drive'), (0.039134398735015265, 'Tampines West')], 'coords': (42032.458094, 38988.218791), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (32531, 32866), 'planningArea': 'Bukit Panjang', 'name': 'Jelebu', 'pop': 335, 'neighbours': [(0.0972972032758665, 'Bangkit'), (0.07151530189462388, 'Fajar'), (0.06605475518571718, 'Saujana'), (0.04541967307938463, 'Teck Whye')], 'coords': (20535.390192, 39769.444512), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (32866, 33187), 'planningArea': 'Choa Chu Kang', 'name': 'Peng Siang', 'pop': 321, 'neighbours': [(0.05357934513244911, 'Keat Hong'), (0.049092201352722395, 'Choa Chu Kang Central'), (0.038361029453521225, 'Choa Chu Kang North'), (0.026033757350004696, 'Teck Whye')], 'coords': (17462.292089, 40146.411316), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (33187, 34142), 'planningArea': 'Woodlands', 'name': 'Woodlands East', 'pop': 955, 'neighbours': [(0.24909618396338976, 'Midview'), (0.13722365828740848, 'Woodlands South'), (0.08112012973177761, 'Sembawang Central'), (0.047753651180600855, 'Sembawang North')], 'coords': (24506.637558, 46991.630027), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (34142, 34689), 'planningArea': 'Sengkang', 'name': 'Sengkang Town Centre', 'pop': 547, 'neighbours': [(0.38269704020667494, 'Rivervale'), (0.20948281145666975, 'Anchorvale'), (0.11002941020168477, 'Matilda'), (0.09868610239532008, 'Punggol Field')], 'coords': (35163.812082, 41501.141857), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (34689, 35190), 'planningArea': 'Hougang', 'name': 'Hougang West', 'pop': 501, 'neighbours': [(0.2396720542045326, 'Trafalgar'), (0.07473536594098086, 'Kovan'), (0.06347211631592913, 'Hougang East'), (0.06300451506480333, 'Kangkar')], 'coords': (33849.220599, 39506.872464), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (35190, 35445), 'planningArea': 'Bukit Panjang', 'name': 'Saujana', 'pop': 255, 'neighbours': [(0.21267087284698513, 'Fajar'), (0.12620301816031967, 'Senja'), (0.06605475518571718, 'Jelebu'), (0.036871693408663475, 'Teck Whye')], 'coords': (20536.714582, 40906.653165), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (35445, 35800), 'planningArea': 'Woodlands', 'name': 'Midview', 'pop': 355, 'neighbours': [(0.24909618396338976, 'Woodlands East'), (0.09169895354312044, 'Woodlands South'), (0.03670353559593632, 'Woodgrove'), (0.03655829201938252, 'Woodlands West')], 'coords': (23349.760085, 46841.114377), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (35800, 36379), 'planningArea': 'Yishun', 'name': 'Yishun West', 'pop': 579, 'neighbours': [(0.14913580098363083, 'Northland'), (0.10147449373438587, 'Yishun East'), (0.08848494096438753, 'Yishun South'), (0.047156437115787576, 'Woodlands East')], 'coords': (27743.266827, 45873.600682), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (36379, 36978), 'planningArea': 'Sengkang', 'name': 'Rivervale', 'pop': 599, 'neighbours': [(0.38269704020667494, 'Sengkang Town Centre'), (0.2351328903922378, 'Punggol Field'), (0.062129487943474455, 'Anchorvale'), (0.05752588008066772, 'Hougang East')], 'coords': (35977.611393, 41060.802457), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (36978, 37124), 'planningArea': 'Bukit Batok', 'name': 'Bukit Batok East', 'pop': 146, 'neighbours': [(0.059127087488538246, 'Bukit Batok Central'), (0.028918012412758144, 'Guilin'), (0.025971037162869685, 'Hillview'), (0.02518109841816715, 'Bukit Batok South')], 'coords': (19566.361359, 36806.301593), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (37124, 37231), 'planningArea': 'Bukit Merah', 'name': 'Telok Blangah Way', 'pop': 107, 'neighbours': [(0.04241161303429543, 'Telok Blangah Rise'), (0.01880830443281789, 'Kampong Tiong Bahru'), (0.017178425925253923, 'Tiong Bahru Station'), (0.01177078384593679, 'Henderson Hill')], 'coords': (26570.51735, 28871.892242), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (37231, 37499), 'planningArea': 'Bukit Panjang', 'name': 'Fajar', 'pop': 268, 'neighbours': [(0.21267087284698513, 'Saujana'), (0.07568527033810468, 'Bangkit'), (0.07151530189462388, 'Jelebu'), (0.03809167338869291, 'Senja')], 'coords': (21080.957329, 40748.092643), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (37499, 37737), 'planningArea': 'Ang Mo Kio', 'name': 'Townsville', 'pop': 238, 'neighbours': [(0.10168892900435988, 'Chong Boon'), (0.0672979821164682, 'Cheng San'), (0.04579382861011293, 'Marymount'), (0.03280696298760327, 'Shangri-la')], 'coords': (29686.46802, 38599.499531), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (37737, 38174), 'planningArea': 'Choa Chu Kang', 'name': 'Yew Tee', 'pop': 437, 'neighbours': [(0.1758278690461748, 'Choa Chu Kang North'), (0.031122105745470606, 'Choa Chu Kang Central'), (0.0233356443652345, 'Teck Whye'), (0.02112307494554621, 'Peng Siang')], 'coords': (18498.113918, 42506.074357), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (38174, 38341), 'planningArea': 'Bukit Merah', 'name': 'Tiong Bahru Station', 'pop': 167, 'neighbours': [(0.07880221716477884, 'Tiong Bahru'), (0.06130055285895344, 'Henderson Hill'), (0.04938013475719582, 'Bukit Ho Swee'), (0.04418555038582969, 'Kampong Tiong Bahru')], 'coords': (27277.469823, 29607.023713), 'infected': 0, 'prob': 0.18}
# {'nodeIndex': (38341, 39023), 'planningArea': 'Jurong West', 'name': 'Jurong West Central', 'pop': 682, 'neighbours': [(0.5470292588098363, 'Yunnan'), (0.14990380789276334, 'Boon Lay Place'), (0.0690383600392235, 'Hong Kah'), (0.05130660673598063, 'Taman Jurong')], 'coords': (13396.626176, 35811.726167), 'infected': 0, 'prob': 0.18}

# %%
# Breaks data into equal chunks. Returns a array of ranges which shows the class breaks
#[(0,33),(33,66),(66,100)]
ranges = []
for i in range(1,6):
    if i == 5:    
        ranges.append((distances[(i-1)*190],distances[-1]))
    else:
        ranges.append((distances[(i-1)*190],distances[(i)*190]))
print ranges
# Out:
# [(4.695977162532835e-06, 0.001131257675818642), (0.001131257675818642, 0.0071748588899590415), (0.0071748588899590415, 0.02203216430531467), (0.02203216430531467, 0.04750678243888015), (0.04750678243888015, 0.5470292588098363)]

# %%
#Insert probabilties for inter-subzone edges. For each subzone, we look at the gravity and assign a probabilty based on it
def bin_pop(value,ranges):
    for i in ranges:
        if i[0]<= value < i[1]:
            return 0.001 + 0.003*ranges.index(i)
    #print value
    return 0.001 + 0.003*4

# for key,n in neighbors.iteritems():
#     for i in n:
#         i.append(bin_pop(i[0],ranges))
# print neighbors

# %%
def make_edge(p):
    return True if random.random() <= p else False

# for pa,n in neighbors.iteritems():
#     cluster1 = list((n for n in f_graph if f_graph.node[n]['location']==pa))
#     for i in n:
#         cluster2 = list((n for n in f_graph if f_graph.node[n]['location']==i[1]))
#         for j in cluster1:
#             for k in cluster2:
#                 if make_edge(i[2]):
#                     f_graph.add_edge(j,k)
                    
#Add edges between subzones
def connectSubGraphs(subZoneData, finalGraph):
    index = {}
    #Create an index of subzone to array index
    for i in range(len(subZoneData)):
        index[subZoneData[i]['name']] = i
        
    for subzone in subZoneData:
        if subzone['pop'] == 0:
            continue
        #Create neighbour array
        neighbours = subzone['neighbours']
        neighbouringNodes = []
        neighbouringProb = []
        nodes = range(subzone['nodeIndex'][0], subzone['nodeIndex'][1])
        for n in neighbours:
            sub = subZoneData[index[n[1]]]
            nodeNumber = sub['nodeIndex'] 
            neighbouringNodes.append(range(nodeNumber[0], nodeNumber[1]))
            neighbouringProb.append(bin_pop(n[0], ranges))
            
        for node in nodes:
            for targetZone in range(len(neighbouringNodes)):
                prob = neighbouringProb[targetZone]
                targetNodes = neighbouringNodes[targetZone]
                for targetNode in targetNodes:
                    if make_edge(prob):
                        finalGraph.add_edge(node, targetNode)
                    
connectSubGraphs(subZoneData, finalGraph)

# %%
# print nx.number_of_edges(f_graph)
# a = list((n for n in f_graph if f_graph.node[n]['location']=='Tampines East'))
# print a[0], a[-1]

# %%
infected_no = 3

# infected_seed = set(random.sample(range(28634,30019),infected_no))
# for i in infected_seed:
#     f_graph.node[i]['status'] = 'I'
    
# for a in range(20):
#     for i in infected_seed:
#         for n in f_graph.neighbors(i):
#             if f_graph.node[n]['status'] != 'I':
#                 f_graph.node[n]['status'] = flip(inf_prob)
                
#     for i,dict in f_graph.nodes_iter(data=True):
#         if dict['status'] == 'I':  
#             loc_count[dict['location']] += 1
#             infected_seed.add(i)        
#     print loc_count
#     filename = "out" + str(a) +'.csv'
#     myFile= open("out" + str(a+1) +'.csv', 'wb' )
#     wtr= csv.writer( myFile )
#     with open(filename, 'rb') as f:
#        reader = csv.reader(f)
#        header = reader.next()
#        wtr.writerow(header + ['Inf_pop day ' + str(a)])
#        for row in reader:
#            wtr.writerow(row + [loc_count[row[1]]])
#     myFile.close()
    
#     for key,value in loc_count.iteritems():
#         value = 0
#     print loc_count

# %%
def seedInfection(subZoneData, finalGraph, location, num):
    nodeIndexRange = 0
    for i in range(len(subZoneData)):
        if subZoneData[i]['name'] == location:
            nodeIndexRange = subZoneData[i]['nodeIndex']
            subZoneData[i]['infected'] = num
    infected_seed = set(random.sample(range(nodeIndexRange[0],nodeIndexRange[1]),num))
    for i in infected_seed:
        finalGraph.node[i]['status'] = 'I'
    
    return infected_seed
        
def stepForward(subZoneData, finalGraph, infected_seed):
    newInfection = set()
    for i in infected_seed:
        for n in finalGraph.neighbors(i):
            if finalGraph.node[n]['status'] != 'I':
                finalGraph.node[n]['status'] = flip(inf_prob)
            if finalGraph.node[n]['status'] == 'I':
                newInfection.add(n)
    for subzone in subZoneData:
        infectCount = 0;
        nodes = range(subzone['nodeIndex'][0], subzone['nodeIndex'][1])
        for n in nodes:
            if finalGraph.node[n]['status'] == 'I':
                infectCount += 1
        subzone['infected'] = infectCount

        
def writeOut(subZoneData, output):
    if len(output) != len(subZoneData):
        print "restructure output"
        output = [[] for i in range(len(subZoneData))]
    for s in range(len(subZoneData)):
        output[s].append(subZoneData[s]['infected'])
        
        
infected_seed = seedInfection(subZoneData, finalGraph, 'Tampines East', 3)
infection = []
writeOut(subZoneData, infection)
print infection
days = 20
for day in range(days):
    stepForward(subZoneData, finalGraph, infected_seed)
    writeOut(subZoneData, infection)

filename = "out.csv"
myFile= open(filename, 'wb' )
wtr= csv.writer( myFile )
with open(filename, 'rb') as f:
    header = range(1, days + 1)
    header.insert(0, "Subzone")
    wtr.writerow(header)
    for i in range(len(infection)):
        row = [subZoneData[i]['name']] + infection[i]
        wtr.writerow(row)
myFile.close()
print "DONE"
# Out:
# restructure output
# []
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# restructure output
# DONE
